# %%
#Import usefull python libraries
import pandas as pd

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
print(f"Nombre d'observations : {df.shape[0]}")
print(f"Nombre de variables : {df.shape[1]}")
# Out:
# Nombre d'observations : 8807
# Nombre de variables : 12

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
print(df.select_dtypes(include='number').columns)  # numériques
print(df.select_dtypes(include='object').columns)  # qualitatives
# Out:
# Index(['release_year'], dtype='object')
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
missing_data = pd.DataFrame({
    'Valeurs manquantes': df.isnull().sum(),
    'Pourcentage (%)': df.isnull().mean() * 100
})
print(missing_data)
# Out:
#               Valeurs manquantes  Pourcentage (%)
# show_id                        0         0.000000
# type                           0         0.000000
# title                          0         0.000000
# director                    2634        29.908028
# cast                         825         9.367549
# country                      831         9.435676
# date_added                    10         0.113546
# release_year                   0         0.000000
# rating                         4         0.045418
# duration                       3         0.034064
# listed_in                      0         0.000000
# description                    0         0.000000

# %%
# !pip install missingno

# %%
import missingno as msno
import matplotlib.pyplot as plt

# %%
# Affichage d'un barplot des valeurs manquantes
msno.bar(df)
plt.show()

# %%
msno.heatmap(df)
plt.show()

# %%
msno.dendrogram(df)
plt.show()

# %%
df.sample(1)
# Out:
#     show_id   type title                        director  \
# 300    s301  Movie  Vivo  Kirk DeMicco, Brandon Jeffords
#
#                                                   cast                country  \
# 300  Lin-Manuel Miranda, Ynairaly Simo, Zoe Saldana...  Canada, United States
#
#          date_added  release_year rating duration  \
# 300  August 6, 2021          2021     PG  100 min
#
#                                       listed_in  \
# 300  Children & Family Movies, Music & Musicals
#
#                                            description
# 300  A music-loving kinkajou embarks on the journey...

# %%
df[df['title'] == "Catch Me If You Can"]
# Out:
#     show_id   type                title          director  \
# 329    s330  Movie  Catch Me If You Can  Steven Spielberg
#
#                                                   cast                country  \
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...  United States, Canada
#
#          date_added  release_year rating duration listed_in  \
# 329  August 1, 2021          2002  PG-13  142 min    Dramas
#
#                                            description
# 329  An FBI agent makes it his mission to put cunni...

# %%
print(df[df['release_year'] == df['release_year'].max()]['title'])
# Out:
# 1                   Blood & Water
# 2                       Ganglands
# 3           Jailbirds New Orleans
# 4                    Kota Factory
# 5                   Midnight Mass
#                   ...
# 1468    What Happened to Mr. Cha?
# 1551                        Hilda
# 1696                 Polly Pocket
# 2920                Love Is Blind
# 8437       The Netflix Afterparty
# Name: title, Length: 592, dtype: object

# %%
import datetime

# Convertir la colonne 'release_year' en format datetime (on suppose 01-01 comme jour et mois)
df['release_date'] = pd.to_datetime(df['release_year'].astype(str), format='%Y')

# Trouver le film le plus récent
most_recent_movie = df.loc[df['release_date'] == df['release_date'].max()]
print(most_recent_movie['title'].iloc[0])
# Out:
# Blood & Water

# %%
# Filtrer les séries (TV Shows)
tv_shows = df[df['type'] == 'TV Show']

# Trouver la série la plus récente
most_recent_tv_show = tv_shows.nlargest(1, 'release_year')

# Afficher le titre de la série la plus récente
print(most_recent_tv_show['title'].iloc[0])
# Out:
# Blood & Water

# %%
# Filtrer uniquement les séries TV (type == 'TV Show')
tv_shows = df[df['type'] == 'TV Show']

# Trouver la série la plus récente en se basant sur l'année de sortie
most_recent_tv_show = tv_shows.loc[tv_shows['release_year'] == tv_shows['release_year'].max()]

# Afficher le titre de la série la plus récente
print(most_recent_tv_show['title'].iloc[0])
# Out:
# Blood & Water

# %%
# Filtrer uniquement les films (type == 'Movie')
movies = df[df['type'] == 'Movie']

# Trouver le film le plus récent en se basant sur l'année de sortie
most_recent_movie = movies.loc[movies['release_year'] == movies['release_year'].max()]

# Afficher le titre du film le plus récent
print(most_recent_movie['title'].iloc[0])
# Out:
# My Little Pony: A New Generation

# %%
# Convertir la colonne 'date_added' en type DateTime
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# Afficher les 5 premières lignes pour vérifier la conversion
print(df['date_added'].head())
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
# Extraire les nombres (en minutes) de la colonne 'duration' et les convertir en int
df['duration'] = df['duration'].str.extract('(\d+)').astype(float)

# Afficher les 5 premières lignes pour vérifier
print(df['duration'].head())
# Out:
# 0    90.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     2.0
# Name: duration, dtype: float64
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kench\AppData\Local\Temp\ipykernel_22244\2033655468.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['duration'] = df['duration'].str.extract('(\d+)').astype(float)

# %%
# Extraire les nombres (en minutes) de la colonne 'duration' et les convertir en int
df['duration'] = df['duration'].str.extract(r'(\d+)').astype(float)

# Afficher les 5 premières lignes pour vérifier
print(df['duration'].head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Extraire les nombres (en minutes) de la colonne 'duration' et les convertir en int
# ----> 2 df['duration'] = df['duration'].str.extract(r'(\d+)').astype(float)
#       4 # Afficher les 5 premières lignes pour vérifier
#       5 print(df['duration'].head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
# Convertir la colonne 'duration' en chaînes de caractères (si nécessaire)
df['duration'] = df['duration'].astype(str)

# Extraire les nombres (en minutes) de la colonne 'duration' et les convertir en float
df['duration'] = df['duration'].str.extract(r'(\d+)').astype(float)

# Afficher les 5 premières lignes pour vérifier
print(df['duration'].head())
# Out:
# 0    90.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     2.0
# Name: duration, dtype: float64

# %%
# Filtrer uniquement les séries (type == 'TV Show')
tv_shows = df[df['type'] == 'TV Show']

# Extraire le nombre de saisons et le convertir en int
tv_shows['duration'] = tv_shows['duration'].str.extract(r'(\d+)').astype(float)

# Afficher les 5 premières lignes pour vérifier
print(tv_shows['duration'].head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 5
#       2 tv_shows = df[df['type'] == 'TV Show']
#       4 # Extraire le nombre de saisons et le convertir en int
# ----> 5 tv_shows['duration'] = tv_shows['duration'].str.extract(r'(\d+)').astype(float)
#       7 # Afficher les 5 premières lignes pour vérifier
#       8 print(tv_shows['duration'].head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
# Filtrer uniquement les séries (type == 'TV Show')
tv_shows = df[df['type'] == 'TV Show']

# Convertir la colonne 'duration' en chaînes de caractères
tv_shows['duration'] = tv_shows['duration'].astype(str)

# Extraire le nombre de saisons et le convertir en int
tv_shows['duration'] = tv_shows['duration'].str.extract(r'(\d+)').astype(float)

# Afficher les 5 premières lignes pour vérifier
print(tv_shows['duration'].head())
# Out:
# 1    2.0
# 2    1.0
# 3    1.0
# 4    2.0
# 5    1.0
# Name: duration, dtype: float64
# C:\Users\kench\AppData\Local\Temp\ipykernel_22244\894082132.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['duration'] = tv_shows['duration'].astype(str)
# C:\Users\kench\AppData\Local\Temp\ipykernel_22244\894082132.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['duration'] = tv_shows['duration'].str.extract(r'(\d+)').astype(float)

# %%
df.loc[:, 'duration'] = df['duration'].astype(str)
df.loc[:, 'duration'] = df['duration'].str.extract(r'(\d+)').astype(float)
# Out:
# C:\Users\kench\AppData\Local\Temp\ipykernel_22244\614840163.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['90.0' '2.0' '1.0' ... '88.0' '88.0' '111.0']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[:, 'duration'] = df['duration'].astype(str)

# %%
# Convertir la colonne 'duration' en chaînes de caractères, en tenant compte de tous les types de données
df['duration'] = df['duration'].astype(str)

# Extraire le nombre de saisons (pour les séries) et les convertir en float
df['duration'] = df['duration'].str.extract(r'(\d+)')

# Convertir les valeurs extraites en float, avec gestion des valeurs manquantes
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')

# Afficher les 5 premières lignes pour vérifier
print(df['duration'].head())
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: duration, dtype: float64

# %%
# Afficher un échantillon des valeurs de la colonne 'duration' pour voir à quoi elles ressemblent
print(df['duration'].unique())
# Out:
# [nan]

# %%
df['listed_in'] = df['listed_in'].str.split(', ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['listed_in'] = df['listed_in'].str.split(', ')
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("netflix_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("netflix_titles.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df['listed_in'] = df['listed_in'].str.split(', ')

# %%
print(df['listed_in'])
# Out:
# 0                                         [Documentaries]
# 1       [International TV Shows, TV Dramas, TV Mysteries]
# 2       [Crime TV Shows, International TV Shows, TV Ac...
# 3                                [Docuseries, Reality TV]
# 4       [International TV Shows, Romantic TV Shows, TV...
#                               ...
# 8802                     [Cult Movies, Dramas, Thrillers]
# 8803             [Kids' TV, Korean TV Shows, TV Comedies]
# 8804                            [Comedies, Horror Movies]
# 8805                 [Children & Family Movies, Comedies]
# 8806     [Dramas, International Movies, Music & Musicals]
# Name: listed_in, Length: 8807, dtype: object

# %%
# Affichage des valeurs uniques pour chaque colonne

print("Valeurs uniques de 'type' :")
print(df['type'].unique())

print("\nValeurs uniques de 'country' :")
print(df['country'].unique())

print("\nValeurs uniques de 'release_year' :")
print(df['release_year'].unique())

print("\nValeurs uniques de 'rating' :")
print(df['rating'].unique())

print("\nValeurs uniques de 'listed_in' :")
print(df['listed_in'].explode().unique())
# Out:
# Valeurs uniques de 'type' :
# ['Movie' 'TV Show']
#
# Valeurs uniques de 'country' :
# ['United States' 'South Africa' nan 'India'
#  'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia'
#  'United Kingdom' 'Germany, Czech Republic' 'Mexico' 'Turkey' 'Australia'
#  'United States, India, France' 'Finland' 'China, Canada, United States'
#  'South Africa, United States, Japan' 'Nigeria' 'Japan'
#  'Spain, United States' 'France' 'Belgium' 'United Kingdom, United States'
#  'United States, United Kingdom' 'France, United States' 'South Korea'
#  'Spain' 'United States, Singapore' 'United Kingdom, Australia, France'
#  'United Kingdom, Australia, France, United States'
#  'United States, Canada' 'Germany, United States'
#  'South Africa, United States' 'United States, Mexico'
#  'United States, Italy, France, Japan'
#  'United States, Italy, Romania, United Kingdom'
#  'Australia, United States' 'Argentina, Venezuela'
# ...

# %%
# Comptage des réalisateurs avec plus d'une œuvre
realisateurs_multiples = df['director'].value_counts()

print(realisateurs_multiples)
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
# Conversion de la colonne 'date_added' en datetime
df['date_added'] = pd.to_datetime(df['date_added'])

# Extraction de l'année d'ajout
df['year_added'] = df['date_added'].dt.year

# Comptage des ajouts par année
films_par_annee = df['year_added'].value_counts().sort_index()

# Affichage de l'année avec le plus d'ajouts
annee_max = films_par_annee.idxmax()
nb_max = films_par_annee.max()

print(f"L'année avec le plus de films ajoutés est {annee_max} avec {nb_max} ajouts.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Conversion de la colonne 'date_added' en datetime
# ----> 2 df['date_added'] = pd.to_datetime(df['date_added'])
#       4 # Extraction de l'année d'ajout
#       5 df['year_added'] = df['date_added'].dt.year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
import datetime

# %%
# Conversion de la colonne 'date_added' en datetime
df['date_added'] = pd.to_datetime(df['date_added'])

# Extraction de l'année d'ajout
df['year_added'] = df['date_added'].dt.year

# Comptage des ajouts par année
films_par_annee = df['year_added'].value_counts().sort_index()

# Affichage de l'année avec le plus d'ajouts
annee_max = films_par_annee.idxmax()
nb_max = films_par_annee.max()

print(f"L'année avec le plus de films ajoutés est {annee_max} avec {nb_max} ajouts.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Conversion de la colonne 'date_added' en datetime
# ----> 2 df['date_added'] = pd.to_datetime(df['date_added'])
#       4 # Extraction de l'année d'ajout
#       5 df['year_added'] = df['date_added'].dt.year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
# Conversion plus robuste de 'date_added' en datetime
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed', errors='coerce')

# Extraction de l'année d'ajout
df['year_added'] = df['date_added'].dt.year

# Comptage des ajouts par année
films_par_annee = df['year_added'].value_counts().sort_index()

# Affichage de l'année avec le plus de contenus ajoutés
annee_max = films_par_annee.idxmax()
nb_max = films_par_annee.max()

print(f"L'année avec le plus de contenus ajoutés est {annee_max} avec {nb_max} ajouts.")
# Out:
# L'année avec le plus de contenus ajoutés est 2019.0 avec 2016 ajouts.

# %%
# 1. Filtrer les séries
tv_shows = df[df['type'] == 'TV Show'].copy()

# 2. Convertir 'date_added' en datetime
tv_shows['date_added'] = pd.to_datetime(tv_shows['date_added'], format='mixed', errors='coerce')

# 3. Extraire l'année d'ajout
tv_shows['year_added'] = tv_shows['date_added'].dt.year

# 4. Compter les ajouts par année
series_par_annee = tv_shows['year_added'].value_counts().sort_index()

# 5. Identifier l'année avec le plus d'ajouts
annee_max = series_par_annee.idxmax()
nb_max = series_par_annee.max()

print(f"L'année avec le plus de séries ajoutées est {annee_max} avec {nb_max} ajouts.")
# Out:
# L'année avec le plus de séries ajoutées est 2020.0 avec 595 ajouts.

# %%
series_par_annee.plot(kind='bar', figsize=(10,6), color='skyblue')
plt.title("Nombre de séries ajoutées par année sur Netflix")
plt.xlabel("Année")
plt.ylabel("Nombre de séries ajoutées")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 series_par_annee.plot(kind='bar', figsize=(10,6), color='skyblue')
# ----> 2 plt.title("Nombre de séries ajoutées par année sur Netflix")
#       3 plt.xlabel("Année")
#       4 plt.ylabel("Nombre de séries ajoutées")
#
# NameError: name 'plt' is not defined

# %%
import matpotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import matpotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matpotlib'

# %%
# !pip install matpotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement matpotlib (from versions: none)
# ERROR: No matching distribution found for matpotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='type', palette='Set2')
plt.title("Répartition du type d'œuvres")
plt.xlabel("Type")
plt.ylabel("Nombre")
plt.show()
# Out:
# C:\Users\kench\AppData\Local\Temp\ipykernel_6320\2162850113.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='Set2')

# %%
top_pays = df['country'].value_counts().nlargest(10)
top_pays.plot(kind='bar', color='coral')
plt.title("Top 10 des pays producteurs d'œuvres")
plt.xlabel("Pays")
plt.ylabel("Nombre d’œuvres")
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df['release_year'], bins=30, kde=True, color='teal')
plt.title("Répartition des œuvres par année de sortie")
plt.xlabel("Année")
plt.ylabel("Nombre")
plt.show()

# %%
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='pastel')
plt.title("Répartition des classifications (ratings)")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\kench\AppData\Local\Temp\ipykernel_6320\1133569773.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='pastel')

# %%
films = df[df['type'] == 'Movie'].copy()
films['duration_minutes'] = films['duration'].str.extract('(\d+)').astype(float)

sns.histplot(films['duration_minutes'], bins=30, color='skyblue')
plt.title("Répartition des durées des films")
plt.xlabel("Durée (minutes)")
plt.ylabel("Nombre de films")
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kench\AppData\Local\Temp\ipykernel_6320\4261464145.py:2: SyntaxWarning: invalid escape sequence '\d'
#   films['duration_minutes'] = films['duration'].str.extract('(\d+)').astype(float)

# %%
series = df[df['type'] == 'TV Show'].copy()
series['saisons'] = series['duration'].str.extract('(\d+)').astype(float)

sns.histplot(series['saisons'], bins=10, color='violet')
plt.title("Répartition des durées des séries (en saisons)")
plt.xlabel("Nombre de saisons")
plt.ylabel("Nombre de séries")
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kench\AppData\Local\Temp\ipykernel_6320\2980202818.py:2: SyntaxWarning: invalid escape sequence '\d'
#   series['saisons'] = series['duration'].str.extract('(\d+)').astype(float)

# %%
df['listed_in'] = df['listed_in'].str.split(', ')
genres_exploded = df.explode('listed_in')
top_genres = genres_exploded['listed_in'].value_counts().nlargest(10)

top_genres.plot(kind='bar', color='orange')
plt.title("Top 10 des genres d’œuvres")
plt.xlabel("Genre")
plt.ylabel("Nombre")
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 5
#       2 genres_exploded = df.explode('listed_in')
#       3 top_genres = genres_exploded['listed_in'].value_counts().nlargest(10)
# ----> 5 top_genres.plot(kind='bar', color='orange')
#       6 plt.title("Top 10 des genres d’œuvres")
#       7 plt.xlabel("Genre")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
# Vérifier les valeurs manquantes ou mal formatées dans 'listed_in'
df['listed_in'] = df['listed_in'].fillna('')

# Assurer que les éléments sont des listes ou des chaînes
df['listed_in'] = df['listed_in'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# Explosion des genres
genres_exploded = df.explode('listed_in')

# Vérifier si l'explosion a réussi (en inspectant la première ligne)
print(genres_exploded.head())

# Affichage des top genres si l'explosion a donné des résultats
if not genres_exploded.empty:
    top_genres = genres_exploded['listed_in'].value_counts().nlargest(10)
    top_genres.plot(kind='bar', color='orange')
    plt.title("Top 10 des genres d’œuvres")
    plt.xlabel("Genre")
    plt.ylabel("Nombre")
    plt.xticks(rotation=45)
    plt.show()
else:
    print("Aucun genre à afficher (données manquantes ou mal formatées).")
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration listed_in  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
# Remplir les valeurs manquantes et s'assurer que 'listed_in' est une liste
df['listed_in'] = df['listed_in'].fillna('')
df['listed_in'] = df['listed_in'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# Explosion des genres
genres_exploded = df.explode('listed_in')

# Vérifier si l'explosion a produit des résultats
if not genres_exploded.empty:
    # Comptage des genres
    genre_counts = genres_exploded['listed_in'].value_counts()

    # Visualisation de la répartition des genres
    genre_counts.plot(kind='bar', color='orange', figsize=(10, 6))
    plt.title("Répartition des genres d’œuvres du dataset")
    plt.xlabel("Genre")
    plt.ylabel("Nombre d'occurrences")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("Aucun genre à afficher (données manquantes ou mal formatées).")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 14
#      11 genre_counts = genres_exploded['listed_in'].value_counts()
#      13 # Visualisation de la répartition des genres
# ---> 14 genre_counts.plot(kind='bar', color='orange', figsize=(10, 6))
#      15 plt.title("Répartition des genres d’œuvres du dataset")
#      16 plt.xlabel("Genre")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
# Vérifier et nettoyer les valeurs manquantes ou mal formatées dans 'listed_in'
df['listed_in'] = df['listed_in'].fillna('')  # Remplacer les valeurs NaN par une chaîne vide
df['listed_in'] = df['listed_in'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# Filtrer les lignes où 'listed_in' n'est pas vide (pour éviter une explosion inutile)
df_non_empty_genres = df[df['listed_in'].str.len() > 0]

# Explosion des genres
genres_exploded = df_non_empty_genres.explode('listed_in')

# Vérifier si l'explosion a produit des résultats valides
if not genres_exploded.empty:
    # Comptage des genres
    genre_counts = genres_exploded['listed_in'].value_counts()

    # Visualisation de la répartition des genres
    genre_counts.plot(kind='bar', color='orange', figsize=(10, 6))
    plt.title("Répartition des genres d’œuvres du dataset")
    plt.xlabel("Genre")
    plt.ylabel("Nombre d'occurrences")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("Aucun genre valide à afficher (données manquantes ou mal formatées).")
# Out:
# Aucun genre valide à afficher (données manquantes ou mal formatées).

# %%
# Remplir les valeurs manquantes par une chaîne vide et s'assurer que 'listed_in' est une liste
df['listed_in'] = df['listed_in'].fillna('')  # Remplacer NaN par une chaîne vide
df['listed_in'] = df['listed_in'].apply(lambda x: x.split(', ') if isinstance(x, str) else [])

# Filtrer les lignes où 'listed_in' contient des genres valides (non vides)
df_non_empty_genres = df[df['listed_in'].str.len() > 0]

# Explosion des genres (créer une ligne pour chaque genre)
genres_exploded = df_non_empty_genres.explode('listed_in')

# Vérification et affichage uniquement si l'explosion a produit des résultats
if not genres_exploded.empty:
    # Comptage des genres
    genre_counts = genres_exploded['listed_in'].value_counts()

    # Visualisation de la répartition des genres
    genre_counts.plot(kind='bar', color='orange', figsize=(10, 6))
    plt.title("Répartition des genres d’œuvres du dataset")
    plt.xlabel("Genre")
    plt.ylabel("Nombre d'occurrences")
    plt.xticks(rotation=45)
    plt.tight_layout()  # Ajuster la mise en page pour éviter les chevauchements
    plt.show()
else:
    print("Aucun genre valide à afficher (données manquantes ou mal formatées).")
# Out:
# Aucun genre valide à afficher (données manquantes ou mal formatées).
